# %% [markdown]
# ---
# title: "Лабораторна робота №1. Інсталяція та налаштування Python-середовища"
# description:
#   Документ зроблено за допомогою [Quarto](https://quarto.org/)
# author: "&copy; Качур Артем (АКІТ-21-2), 2023"
# date: "09/18/2023"
# lang: ukr
# format:
#   html:
#     code-fold: true
#     toc: true # меню
#     toc_float: # спливаюче меню
#       collapsed: true # авто
#       number_sections: true
# jupyter: python3
# ---

# %% [markdown]
# __Мета:__ _quick start для роботи з python3 у середовищі IDE PyCharm системою контроля версій git._

# %% [markdown]
# ::: callout-note
# ## Примітка
# Перед виконанням лабораторної роботи необхідно опрацювати матеріал __Лекції 1__.
# :::

# %% [markdown]
# #### Що ви будете вміти?
# * Інсталювати дистрибутив Python.
# * Інсталювати та налаштовувати IDE PyCharm.
# * Створювати Python-проєкт у PyCharm та зв'язувати його з СКВ git.
# * Писати і відлагоджувати прості програми на python у середовищі PyCharm.
# * Комітити написаний код у віддалений репозиторій на на GitHub

# %% [markdown]
# ## Інсталяція Python

# %% [markdown]
# 1. Ідемо на [офіційний сайт Python](https://www.python.org/downloads/).
#
# 1. Завантажуємо та встановлюємо актуальну версію дистрибутиву Python3.
#
# 1. Встановлюємо python, (бажано прийняти праметри інсталяції за замовчанням).
#
# 1. Запускаємо консоль `cmd` і запускаємо python командою `python`:

# %% [markdown]
# ![image.png](attachment:0ccb24c6-f963-4516-bb30-a90f6cd4d43e.png)

# %% [markdown]
# Якщо інтерпретатор встановлений правильно, має з'явитися наступний інтерфейс взаємодії з ним:

# %% [markdown]
# ![image.png](attachment:780ef5b2-2c0f-4457-9462-f967616101e7.png)

# %% [markdown]
# Для виходу з режиму роботи з інтерпретаром назад у консоль потрібно натиснути комбінпцію клавіш `Ctrl-z`.

# %% [markdown]
# ## Інсталяція та налаштування IDE PyCharm

# %% [markdown]
# ### Інсталяція

# %% [markdown]
# Після встановлення інтерпретатора python потрібно завантажити, встановити і налаштувати IDE PyCharm. Для цього необхідно:
#
# 1. Завантажити безкоштовну community версію, звернувшись за [посиланням](https://www.jetbrains.com/ru-ru/pycharm/download/#section=windows).
#
# 1. Виконати інсталяцію IDE PytCharm. При інсталяції __важливо не забути проапдейти змінну оточення PATH__, для того щоби можна було з поточного каталогу просто завантажувати код у середовище розробки.
#
# 1. Після завершення інсталяції обов'язково перезавантажити комп'ютер.
#
# 1. Запустити IDE PyCharm. Якщо всі попередні кроки виконано коректно, на екрані має з'явитися приблизно таке:

# %% [markdown]
# ![image.png](attachment:c08e3378-c55d-47dd-82d0-ee5ef9ceda02.png)

# %% [markdown]
# ### Створення Python-проєкта

# %% [markdown]
# Після інсталяції ми маємо три наступні можливості:
#
# * створити новий проект (New Project);
# * відкрити існуючий (Open);
# * імпортувати його віддаленого репозиторію, наприклад, з GitHub.
#
# Розглянемо перший варіант -- створимо проєкт з нуля.
# Для цього у вікні, що відкрилося, потрібно звернути увагу на наступні важливі речі:
#
# * спосіб встановлення віртуального середовища;
# * місце розташування проєкта, що створюється;
# * версію базового інтерпретатора.

# %% [markdown]
# ![image.png](attachment:b05f6cbb-4ef9-47ba-8e88-89b904c1b8d7.png)

# %% [markdown]
# Після створення проєкта ми маємо опинитися в середовищі, яке буде мати наступний вигляд.

# %% [markdown]
# ![image.png](attachment:591d3d29-869c-4007-921e-e62f010451a0.png)

# %% [markdown]
# Це так званий старий інтерфейс програми. Можна встановити новий (_File\Settings\New UI_)
# і перезавантажити PyCharm.

# %% [markdown]
# Для того, щоби встановити потрібні пакети, можна скористатися менеджером пакетів `pip` і зробити це в консолі, або перейти до _File/Settings/Project/Python Interpretator_.

# %% [markdown]
# ## Написання та запуск коду. Налаштування PyCharm-Git-GitHub середовища

# %% [markdown]
# Для ефективної, зокрема командної, роботи потрібно створений проект зв'язати з системою контроля версій (СКВ).
# Існують різні СКВ, найбільш популярною з яких наразі є [Git](https://git-scm.com/).
# Для того, щоби налаштувати середовище PyCharm-Git-GitHub необхідно:
#
# 1. Завантажити і налаштувати СКВ Git на своєму локальному комп'ютері.
# 1. Створити акаунт на ресурсі [GitHub](https://github.com/).
# 1. Створити репозиторій на GitHub у своєму акаунті.
# 1. Зв'язати його із створеним у PyCharm проєктом на python.
#
# Будемо вважати, що п. 1-3 вами виконані і покажемо як виконати п. 4.

# %% [markdown]
# ### Cтворення git-репозиторію і зв'язування його з python-проєктом

# %% [markdown]
# ![image.png](attachment:cc7551ec-b6a4-4e75-8d12-10e25dfd0731.png)

# %% [markdown]
# Ця команда аналогічна команді `git init`, яка ініціює створення git-репозиторію у поточному каталозі, в якому знаходиться наш python-проєкт.
# Наступний крок -- зв'язування його з віддаленим репозиторієм, який знаходиться на GitHub.

# %% [markdown]
# ### Зв'язування створеного python-проєкта з відддаленим Git-репозиторієм

# %% [markdown]
# ![image.png](attachment:6e67076f-17a3-4975-b774-305a7d791db2.png)

# %% [markdown]
# Зверніть увагу, що пункт меню змінив назву з VCS на Git.
# Далі потрібно скопіювати посилання з GitHub-репозиторію і вставити її у віповідне поле в PyCharm. При цьому слід враховувати протокол, за яким налаштована взаємодія Git-на локальному комп'ютері з віддаленим репозиторієм: SSH або HTTPS.

# %% [markdown]
# ![image.png](attachment:171e539c-45fb-4117-8bca-1db74c75f058.png)

# %% [markdown]
# ![image.png](attachment:ed348718-f939-4d11-9942-ed2e0f6ccd63.png)

# %% [markdown]
# ### Робота з віддаленим репозиторієм

# %% [markdown]
# Будь-які зміни в проєкті можуть бути додані в індекс Git-репозиторію і закомічені у репозиторій на локальній машині. Після того копія локального репо може бути записана у віддалений репо на GitHub.
# Перелік необхідних команд Git, якщо викоростовувати для цього консоль, може бути таким:
#
# * `git status` - перевірка статусу файлів;
#
# * `git add .` - додавання всіх новостворених файлів у індекс;
#
# * `git commit -m "коментар до коміту"` - додавання змін у локальний Git-репозиторій;
#
# * `git push -u origin master` - відсилання поточної локальної копії Git-репо на GitHub-репозиторій.
#
# Початківці це можуть зробити простіше через меню PyCharm.

# %% [markdown]
# Після цього ми будемо мати налаштоване середовище для ефективного написання та відлагодження коду на Python з можливістю збереження всіх версій проєкту як у локальному Git-середовищі, так і у віддаленому на GiHub.

# %% [markdown]
# ## Завдання для самостіної роботи
#
# 1. Завантажити і встановити `Python`.
#
# 1. Завантажити, встановити і налаштувати IDE PyCharm у відповідності з інструкціями, описаними вище
#
# 1. Завантажити, встановити і налаштувати систему контроля версій Git на вашому робочому комп'ютері.
#
# 1. Створити акаунт на GitHub та стоврити в ньому новий проєкт з іменем
# __StudentLastName_project__.
#
# 1. Налаштувати зв'язок PyCharm з Git.
#
# 1. Налаштувати зв'язок PyCharm з віддаленим репозиторієм на GitHub.
#
# 1. Створити файл __lab_1_StudentLastName.py__ з кодом, який виводить фразу __"Привіт, Ваше Прізвище"__.
#
# 1. Закомітити файл у локальний репозиторій.
#
# 1. Відправити ("запушити") поточну версію Git-проєкта у віддалений репозиторій на GitHub.
#
# 1. Звіт має складатися з файлу (за основу взяти __цей Python-зошит__) з відповідними скріншотами `lab_1_StudentLastName.ipynb`. У звіті має бути посилання на Ваш GitHub-репозиторій з Вашим проєктом та відповіді на контролі запитання.
#
# [Посилання на мій GitHub-репозиторій.](https://github.com/ArtemKachur7/StudentKachur_project/tree/master)
#
#
#
# ![image.png](attachment:8683db27-3217-43f2-851c-37e063f7408f.png)

# %%
# %run lab_1_StudentKachur.py
# Out:
# Привіт, Качур

# %% [markdown]
# ## Контрольні запитання
# 1. У чому відмінність інтерпретатора від компілятора? Python – компілятор чи інтерпретатор?
#
# Інтерпретатор читає кожен рядок коду , а компілятор повністю перетворює початковий код у машинний. Python — інтепретатор.
#
# 2. Що таке IDE PyCharm?
#
# Це середовище розробки для мови програмування Python.
#
# 3. Що таке система контроля версій (СКВ) і для чого вона призначена? У чому принципова відмінність СКВ SVN та GIT?
# CКВ — система контроля версій , це програмне забезпечення, що використовується для відстеження змін в файлах та проектах програмного коду.
# Принципова відмінність між СКВ SVN та GIT в тому , що у SVN є центральний сервер проекту з яким всі копії розробників синхронізуються , а у GIT у кожного розробника своя копія зі своєю історією , яка може не впливати на центральний сервер.
#
# 4. Що відбувається при виконанні команди git add .?
#
# Всі новостворені файли додаються у індекс.
#
# 5. Що відбувається при виконанні команди git commit?
#
# Додаються  зміни у локальний GIT-репозиторій
#
# 6. Якою Git-командою виконується розміщення локальної копії Git-репозиторію проєкта на віддаленому, що знаходиться на GitHub?
#
# git push -u origin master

# %% [markdown]
# ## References

# %% [markdown]
# 1. [Anaconda (Python distribution)](https://uk.wikipedia.org/wiki/Anaconda_(Python_distribution))
# 2. [Conda](https://conda.io/en/latest/)
# 3. [Pro Git Book](https://git-scm.com/book/en/v2)
# 4. [OpenEDG Python Institute](https://pythoninstitute.org/)
# 5. [Cisco. Networking Academy](https://www.netacad.com/)
# 6. [ЧТО ТАКОЕ ЯП PYTHON? УСТАНОВКА ПАЙТОНА НА WINDOWS 11 !](https://www.youtube.com/watch?v=nQMddf_6KoM&list=PLV0FNhq3XMOKljD7POtuWVAZn8wXcn4-L)
# 1. [Научно-издательская система Quarto](https://data-visualization-blog.netlify.app/posts/quarto/)
# 1. [The Python Standard Library](https://docs.python.org/3/library/index.html)
# 1. [Callout Blocks. Markdown Syntax](https://quarto.org/docs/authoring/callouts.html)
